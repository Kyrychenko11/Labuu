# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

from tensorflow.keras.layers import (Input, Rescaling, RandomFlip, RandomRotation, RandomContrast,
                                     Conv2D, BatchNormalization, MaxPool2D,
                                     GlobalAveragePooling2D, Dense, Dropout)

from tensorflow.keras.regularizers import l2

# %% [markdown]
# ВАРІАНТ 1

# %%
# Шлях до директорії з тренувальними зображеннями
train_images_dir = '/kaggle/input/gtsrb-german-traffic-sign/Train'

# Списки для зображень і міток
images = []
labels = []

# Проходимо по кожній папці (класу)
for class_folder in os.listdir(train_images_dir):
    class_folder_path = os.path.join(train_images_dir, class_folder)
    
    # Перевіряємо, чи є це папка, і якщо так, то зберігаємо зображення
    if os.path.isdir(class_folder_path):
        for image_file in os.listdir(class_folder_path):
            # Створення шляху до зображення
            img_path = os.path.join(class_folder_path, image_file)
            # Завантаження зображення
            img = image.load_img(img_path, target_size=(32, 32))  # зміна розміру на 32x32
            img_array = image.img_to_array(img)
            
            # Додаємо зображення в список
            images.append(img_array)
            # Додаємо мітку класу (число)
            labels.append(int(class_folder))

# Перетворюємо списки у NumPy масиви
images = np.array(images)
labels = np.array(labels)

# Перевірка форми даних
print(f"Форма зображень: {images.shape}")
print(f"Мітки класів: {labels.shape}")
# Out:
# Форма зображень: (39209, 32, 32, 3)
# Мітки класів: (39209,)

# %%
# Поділ на тренувальні та тестові дані
X_train, X_test, y_train, y_test = train_test_split(
    images, labels, test_size=0.2, random_state=42, stratify=labels
)

print(f"Розмір тренувальних даних: {X_train.shape}")
print(f"Розмір тестових даних: {X_test.shape}")
# Out:
# Розмір тренувальних даних: (31367, 32, 32, 3)
# Розмір тестових даних: (7842, 32, 32, 3)

# %%
# Перетворення міток на one-hot encoding
y_train = to_categorical(y_train, num_classes=43)
y_test = to_categorical(y_test, num_classes=43)

print(f"Форма y_train після перетворення: {y_train.shape}")  # Очікується (кількість_зразків, 43)
print(f"Форма y_test після перетворення: {y_test.shape}")    # Очікується (кількість_зразків, 43)
# Out:
# Форма y_train після перетворення: (31367, 43)
# Форма y_test після перетворення: (7842, 43)

# %%
height, width, channels = 32, 32, 3  
NUM_CATEGORIES = 43  # Кількість класів для GTSRB

# Створення моделі
model = Sequential([
    Input(shape=(height, width, channels)),

    # Нормалізація + аугментації 
    Rescaling(1./255),
    RandomFlip("horizontal"),           
    RandomRotation(0.05),
    RandomContrast(0.1),

    # Блок 1
    Conv2D(32, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(32, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPool2D(),

    # Блок 2
    Conv2D(64, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    Conv2D(64, (3,3), padding="same", activation="relu"),
    BatchNormalization(),
    MaxPool2D(),

    # Блок 3
    Conv2D(128, (3,3), padding="same", activation="relu", kernel_regularizer=l2(1e-4)),
    BatchNormalization(),
    MaxPool2D(),

    GlobalAveragePooling2D(),
    Dropout(0.5),
    Dense(128, activation="relu"),
    Dropout(0.3),
    Dense(NUM_CATEGORIES, activation="softmax")
])

# %%
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import TopKCategoricalAccuracy

LOSS = CategoricalCrossentropy()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=LOSS,
    metrics=[
        "accuracy",                  
        TopKCategoricalAccuracy(k=3, name="top3")
    ]
)

cb = [
    tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=8, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),  # щоб працював val_accuracy і val_loss
    epochs=50,
    batch_size=32,
    shuffle=True,
    callbacks=cb,
    verbose=1
)
# Out:
# Epoch 1/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.1411 - loss: 3.4003 - top3: 0.2863 - val_accuracy: 0.5024 - val_loss: 1.7404 - val_top3: 0.7311 - learning_rate: 3.0000e-04
# Epoch 2/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.4775 - loss: 1.7471 - top3: 0.7158 - val_accuracy: 0.7780 - val_loss: 0.8985 - val_top3: 0.9329 - learning_rate: 3.0000e-04
# Epoch 3/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.7073 - loss: 0.9697 - top3: 0.8935 - val_accuracy: 0.8939 - val_loss: 0.3903 - val_top3: 0.9862 - learning_rate: 3.0000e-04
# Epoch 4/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.8153 - loss: 0.5964 - top3: 0.9596 - val_accuracy: 0.9214 - val_loss: 0.2832 - val_top3: 0.9938 - learning_rate: 3.0000e-04
# Epoch 5/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.8733 - loss: 0.4076 - top3: 0.9795 - val_accuracy: 0.9404 - val_loss: 0.1973 - val_top3: 0.9960 - learning_rate: 3.0000e-04
# Epoch 6/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9027 - loss: 0.3167 - top3: 0.9881 - val_accuracy: 0.9524 - val_loss: 0.1486 - val_top3: 0.9973 - learning_rate: 3.0000e-04
# Epoch 7/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9150 - loss: 0.2723 - top3: 0.9899 - val_accuracy: 0.9717 - val_loss: 0.1020 - val_top3: 0.9986 - learning_rate: 3.0000e-04
# Epoch 8/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9300 - loss: 0.2263 - top3: 0.9926 - val_accuracy: 0.9714 - val_loss: 0.1080 - val_top3: 0.9980 - learning_rate: 3.0000e-04
# Epoch 9/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9393 - loss: 0.1988 - top3: 0.9932 - val_accuracy: 0.9750 - val_loss: 0.0909 - val_top3: 0.9982 - learning_rate: 3.0000e-04
# Epoch 10/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9494 - loss: 0.1748 - top3: 0.9954 - val_accuracy: 0.9778 - val_loss: 0.0707 - val_top3: 0.9992 - learning_rate: 3.0000e-04
# Epoch 11/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9533 - loss: 0.1582 - top3: 0.9951 - val_accuracy: 0.9791 - val_loss: 0.0783 - val_top3: 0.9989 - learning_rate: 3.0000e-04
# Epoch 12/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9567 - loss: 0.1468 - top3: 0.9958 - val_accuracy: 0.9690 - val_loss: 0.0958 - val_top3: 0.9980 - learning_rate: 3.0000e-04
# Epoch 13/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9582 - loss: 0.1351 - top3: 0.9971 - val_accuracy: 0.9856 - val_loss: 0.0582 - val_top3: 0.9987 - learning_rate: 3.0000e-04
# Epoch 14/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9640 - loss: 0.1271 - top3: 0.9967 - val_accuracy: 0.9809 - val_loss: 0.0745 - val_top3: 0.9985 - learning_rate: 3.0000e-04
# Epoch 15/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9631 - loss: 0.1206 - top3: 0.9967 - val_accuracy: 0.9758 - val_loss: 0.0914 - val_top3: 0.9981 - learning_rate: 3.0000e-04
# Epoch 16/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9675 - loss: 0.1132 - top3: 0.9974 - val_accuracy: 0.9874 - val_loss: 0.0580 - val_top3: 0.9990 - learning_rate: 3.0000e-04
# Epoch 17/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9690 - loss: 0.1082 - top3: 0.9974 - val_accuracy: 0.9885 - val_loss: 0.0513 - val_top3: 0.9990 - learning_rate: 3.0000e-04
# Epoch 18/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9694 - loss: 0.1082 - top3: 0.9969 - val_accuracy: 0.9912 - val_loss: 0.0465 - val_top3: 0.9994 - learning_rate: 3.0000e-04
# Epoch 19/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9723 - loss: 0.0993 - top3: 0.9981 - val_accuracy: 0.9867 - val_loss: 0.0563 - val_top3: 0.9994 - learning_rate: 3.0000e-04
# Epoch 20/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9738 - loss: 0.0915 - top3: 0.9982 - val_accuracy: 0.9902 - val_loss: 0.0507 - val_top3: 0.9991 - learning_rate: 3.0000e-04
# Epoch 21/50
# 979/981 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9739 - loss: 0.0945 - top3: 0.9982
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9739 - loss: 0.0945 - top3: 0.9982 - val_accuracy: 0.9902 - val_loss: 0.0489 - val_top3: 0.9996 - learning_rate: 3.0000e-04
# Epoch 22/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9808 - loss: 0.0763 - top3: 0.9986 - val_accuracy: 0.9920 - val_loss: 0.0410 - val_top3: 0.9994 - learning_rate: 1.5000e-04
# Epoch 23/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9832 - loss: 0.0661 - top3: 0.9990 - val_accuracy: 0.9925 - val_loss: 0.0390 - val_top3: 0.9994 - learning_rate: 1.5000e-04
# Epoch 24/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9851 - loss: 0.0617 - top3: 0.9993 - val_accuracy: 0.9949 - val_loss: 0.0342 - val_top3: 0.9996 - learning_rate: 1.5000e-04
# Epoch 25/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9848 - loss: 0.0629 - top3: 0.9993 - val_accuracy: 0.9931 - val_loss: 0.0358 - val_top3: 0.9995 - learning_rate: 1.5000e-04
# Epoch 26/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9870 - loss: 0.0585 - top3: 0.9991 - val_accuracy: 0.9938 - val_loss: 0.0365 - val_top3: 0.9995 - learning_rate: 1.5000e-04
# Epoch 27/50
# 980/981 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9862 - loss: 0.0612 - top3: 0.9989
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9862 - loss: 0.0612 - top3: 0.9989 - val_accuracy: 0.9931 - val_loss: 0.0400 - val_top3: 0.9992 - learning_rate: 1.5000e-04
# Epoch 28/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9870 - loss: 0.0565 - top3: 0.9993 - val_accuracy: 0.9953 - val_loss: 0.0330 - val_top3: 0.9997 - learning_rate: 7.5000e-05
# Epoch 29/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9900 - loss: 0.0472 - top3: 0.9997 - val_accuracy: 0.9941 - val_loss: 0.0319 - val_top3: 0.9997 - learning_rate: 7.5000e-05
# Epoch 30/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9895 - loss: 0.0487 - top3: 0.9996 - val_accuracy: 0.9948 - val_loss: 0.0313 - val_top3: 0.9995 - learning_rate: 7.5000e-05
# Epoch 31/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9900 - loss: 0.0444 - top3: 0.9997 - val_accuracy: 0.9936 - val_loss: 0.0350 - val_top3: 0.9996 - learning_rate: 7.5000e-05
# Epoch 32/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9906 - loss: 0.0434 - top3: 0.9996 - val_accuracy: 0.9943 - val_loss: 0.0336 - val_top3: 0.9995 - learning_rate: 7.5000e-05
# Epoch 33/50
# 978/981 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9908 - loss: 0.0439 - top3: 0.9998
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9908 - loss: 0.0439 - top3: 0.9998 - val_accuracy: 0.9952 - val_loss: 0.0315 - val_top3: 0.9995 - learning_rate: 7.5000e-05
# Epoch 34/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9920 - loss: 0.0411 - top3: 0.9998 - val_accuracy: 0.9957 - val_loss: 0.0293 - val_top3: 0.9995 - learning_rate: 3.7500e-05
# Epoch 35/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9929 - loss: 0.0380 - top3: 0.9998 - val_accuracy: 0.9962 - val_loss: 0.0279 - val_top3: 0.9995 - learning_rate: 3.7500e-05
# Epoch 36/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9928 - loss: 0.0374 - top3: 0.9997 - val_accuracy: 0.9954 - val_loss: 0.0290 - val_top3: 0.9996 - learning_rate: 3.7500e-05
# Epoch 37/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9927 - loss: 0.0372 - top3: 0.9997 - val_accuracy: 0.9958 - val_loss: 0.0282 - val_top3: 0.9995 - learning_rate: 3.7500e-05
# Epoch 38/50
# 980/981 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9931 - loss: 0.0367 - top3: 0.9999
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9931 - loss: 0.0367 - top3: 0.9999 - val_accuracy: 0.9964 - val_loss: 0.0281 - val_top3: 0.9995 - learning_rate: 3.7500e-05
# Epoch 39/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9939 - loss: 0.0353 - top3: 0.9997 - val_accuracy: 0.9962 - val_loss: 0.0280 - val_top3: 0.9995 - learning_rate: 1.8750e-05
# Epoch 40/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9924 - loss: 0.0363 - top3: 0.9999 - val_accuracy: 0.9964 - val_loss: 0.0273 - val_top3: 0.9995 - learning_rate: 1.8750e-05
# Epoch 41/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9936 - loss: 0.0360 - top3: 0.9996 - val_accuracy: 0.9959 - val_loss: 0.0277 - val_top3: 0.9995 - learning_rate: 1.8750e-05
# Epoch 42/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9936 - loss: 0.0342 - top3: 0.9998 - val_accuracy: 0.9968 - val_loss: 0.0258 - val_top3: 0.9996 - learning_rate: 1.8750e-05
# Epoch 43/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9941 - loss: 0.0343 - top3: 0.9996 - val_accuracy: 0.9962 - val_loss: 0.0281 - val_top3: 0.9995 - learning_rate: 1.8750e-05
# Epoch 44/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9936 - loss: 0.0341 - top3: 0.9999 - val_accuracy: 0.9972 - val_loss: 0.0260 - val_top3: 0.9995 - learning_rate: 1.8750e-05
# Epoch 45/50
# 978/981 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9938 - loss: 0.0332 - top3: 0.9997
# Epoch 45: ReduceLROnPlateau reducing learning rate to 9.375000445288606e-06.
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9938 - loss: 0.0332 - top3: 0.9997 - val_accuracy: 0.9963 - val_loss: 0.0262 - val_top3: 0.9995 - learning_rate: 1.8750e-05
# Epoch 46/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9939 - loss: 0.0339 - top3: 0.9997 - val_accuracy: 0.9964 - val_loss: 0.0261 - val_top3: 0.9995 - learning_rate: 9.3750e-06
# Epoch 47/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9945 - loss: 0.0321 - top3: 0.9999 - val_accuracy: 0.9968 - val_loss: 0.0263 - val_top3: 0.9995 - learning_rate: 9.3750e-06
# Epoch 48/50
# 979/981 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9933 - loss: 0.0343 - top3: 0.9997
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.687500222644303e-06.
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9933 - loss: 0.0343 - top3: 0.9997 - val_accuracy: 0.9964 - val_loss: 0.0258 - val_top3: 0.9995 - learning_rate: 9.3750e-06
# Epoch 49/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9940 - loss: 0.0338 - top3: 0.9999 - val_accuracy: 0.9969 - val_loss: 0.0257 - val_top3: 0.9995 - learning_rate: 4.6875e-06
# Epoch 50/50
# 981/981 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9953 - loss: 0.0306 - top3: 0.9999 - val_accuracy: 0.9967 - val_loss: 0.0257 - val_top3: 0.9995 - learning_rate: 4.6875e-06

# %%
training_accuracy = history.history["accuracy"]
training_loss = history.history["loss"]
validation_accuracy = history.history["val_accuracy"]
validation_loss = history.history["val_loss"]

# %%
plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
plt.plot(training_accuracy, color = "red", label = "Training Accuracy")
plt.plot(validation_accuracy, color = "cyan", label = "Validation Accuracy")
plt.legend()
plt.grid(True)
plt.title("Accuracy")
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")

plt.subplot(1, 2, 2)
plt.plot(training_loss, color = "red", label = "Training Loss")
plt.plot(validation_loss, color = "cyan", label = "Validation Loss")
plt.grid(True)
plt.legend()
plt.title("Loss")
plt.xlabel("Number of epochs")
plt.ylabel("Loss")

plt.tight_layout()
plt.show()

# %%
random_indices = np.random.choice(len(X_test), size=10, replace=False)

# Прогнозування класів для тестових даних
y_pred = model.predict(X_test)

# Виведення зображень та їхніх прогнозованих і справжніх класів
plt.figure(figsize=(15, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[idx])  # Показуємо зображення
    plt.axis('off')
    
    true_class = np.argmax(y_test[idx])  # Справжній клас
    predicted_class = np.argmax(y_pred[idx])  # Прогнозований клас
    
    plt.title(f"True: {true_class}, Pred: {predicted_class}")

plt.tight_layout()
plt.show()
# Out:
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
